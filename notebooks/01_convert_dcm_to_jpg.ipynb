# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pydicom
from PIL import Image
from pathlib import Path

# %%
def save(source_dcm_image_path: Path, target_dcm_dir: Path):
    dcm_image = pydicom.dcmread(source_dcm_image_path)
    images_array = dcm_image.pixel_array.astype(np.float32)
    conv_imgs_list = []
    for i, img_arr in enumerate(images_array):
        inter_folder = "post_pm" if "PM" in str(source_dcm_image_path) else "post"
        target_dcm_image_path = Path(os.path.join(
            target_dcm_dir, inter_folder, source_dcm_image_path.parts[-1].replace(".dcm", f"_{i}.jpg")
        ))
        target_dcm_image_path.parent.mkdir(parents=True, exist_ok=True)
        img_arr = (np.maximum(img_arr, 0) / img_arr.max()) * 255
        img_arr = np.uint8(img_arr)
        img = Image.fromarray(img_arr)
        img.save(str(target_dcm_image_path))
        conv_imgs_list.append(img_arr)
    conv_imgs_arr = np.array(conv_imgs_list)
    return conv_imgs_arr

# %%
source_dcm_image_path = Path("../data/curated/drsbru/DATA_DICOM/drsbru_066/drsbru_066_POST.dcm")
target_dcm_dir = Path("../data/processed/drsbru/jpgs/drsbru_066/")
conv_imgs_arr = save(source_dcm_image_path, target_dcm_dir)

# %%
inputdir = Path("../data/curated/drsbru/DATA_DICOM/")
targetdir = Path("../data/processed/drsbru/jpgs")
inputdir.mkdir(parents=True, exist_ok=True)
for i in os.scandir(inputdir):
    for j in os.scandir(i.path):
        target_dcm_dir = os.path.join(targetdir, (Path(j).parts[-2]))
        source_dcm_image_path = Path(j.path)
        conv_imgs_arr = save(source_dcm_image_path, target_dcm_dir)
        print(f"[INFO] Saved {len(conv_imgs_arr)} images to {target_dcm_dir}")
# Out:
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_066
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_012
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_012
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_023
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_023
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_078
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_078
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_043
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_043
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_050
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_050
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_049
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_079
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_003
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_003
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_016
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_016
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_041
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_041
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_071
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_071
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_024
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_024
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_070
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_070
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_091
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_004
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_004
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_001
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_001
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_035
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_035
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_014
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_060
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_060
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_048
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_048
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_067
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_067
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_072
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_033
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_033
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_010
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_010
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_093
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_093
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_018
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_028
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_028
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_054
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_054
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_039
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_039
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_047
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_047
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_022
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_022
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_011
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_011
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_059
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_009
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_009
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_081
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_081
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_002
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_002
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_063
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_063
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_058
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_058
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_037
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_037
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_025
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_083
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_083
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_089
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_089
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_084
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_084
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_069
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_031
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_031
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_040
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_040
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_021
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_021
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_055
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_055
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_075
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_075
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_056
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_056
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_029
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_052
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_052
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_061
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_061
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_006
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_073
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_073
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_013
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_013
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_096
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_096
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_100
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_100
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_051
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_051
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_085
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_085
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_090
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_090
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_005
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_005
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_098
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_098
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_044
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_044
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_092
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_092
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_068
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_068
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_095
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_095
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_064
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_064
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_097
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_097
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_015
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_015
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_007
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_027
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_027
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_088
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_088
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_046
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_046
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_034
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_034
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_057
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_057
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_082
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_082
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_077
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_077
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_053
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_053
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_086
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_086
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_036
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_036
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_062
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_062
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_074
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_074
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_030
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_030
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_045
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_045
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_038
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_019
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_019
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_094
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_099
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_099
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_032
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_032
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_020
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_020
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_026
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_026
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_017
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_017
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_076
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_076
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_042
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_042
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_065
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_065
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_008
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_008
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_087
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_087
# [INFO] Saved 12 images to ../data/processed/drsbru/jpgs/drsbru_080
# [INFO] Saved 120 images to ../data/processed/drsbru/jpgs/drsbru_080

# %%
inputdir = Path("../data/curated/drshyb/DATA_DICOM/")
targetdir = Path("../data/processed/drshyb/jpgs")
inputdir.mkdir(parents=True, exist_ok=True)
for i in os.scandir(inputdir):
    for j in os.scandir(i.path):
        target_dcm_dir = os.path.join(targetdir, (Path(j).parts[-2]))
        source_dcm_image_path = Path(j.path)
        conv_imgs_arr = save(source_dcm_image_path, target_dcm_dir)
        print(f"[INFO] Saved {len(conv_imgs_arr)} images to {target_dcm_dir}")
# Out:
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_009
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_009
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_010
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_010
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_008
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_008
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_003
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_003
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_012
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_012
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_013
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_013
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_018
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_018
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_019
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_019
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_011
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_011
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_002
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_002
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_015
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_015
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_007
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_007
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_005
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_005
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_001
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_001
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_014
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_014
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_006
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_006
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_004
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_004
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_017
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_017
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_016
# [INFO] Saved 120 images to ../data/processed/drshyb/jpgs/drshyb_016

# %%
inputdir = Path("../data/curated/drslund/DATA_DICOM/")
targetdir = Path("../data/processed/drslund/jpgs")
inputdir.mkdir(parents=True, exist_ok=True)
for i in os.scandir(inputdir):
    for j in os.scandir(i.path):
        target_dcm_dir = os.path.join(targetdir, (Path(j).parts[-2]))
        source_dcm_image_path = Path(j.path)
        conv_imgs_arr = save(source_dcm_image_path, target_dcm_dir)
        print(f"[INFO] Saved {len(conv_imgs_arr)} images to {target_dcm_dir}")
# Out:
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_001
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_001
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_001
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_001
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_001
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_004
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_004
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_004
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_004
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_004
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_003
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_003
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_003
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_003
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_003
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_006
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_006
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_006
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_006
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_006
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_002
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_002
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_002
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_002
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_002
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_005
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_005
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_005
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_005
# [INFO] Saved 120 images to ../data/processed/drslund/jpgs/drslund_005

# %%
inputdir = Path("../data/curated/drsmich/DATA_DICOM/")
targetdir = Path("../data/processed/drsmich/jpgs")
inputdir.mkdir(parents=True, exist_ok=True)
for i in os.scandir(inputdir):
    for j in os.scandir(i.path):
        target_dcm_dir = os.path.join(targetdir, (Path(j).parts[-2]))
        source_dcm_image_path = Path(j.path)
        conv_imgs_arr = save(source_dcm_image_path, target_dcm_dir)
        print(f"[INFO] Saved {len(conv_imgs_arr)} images to {target_dcm_dir}")
# Out:
# [INFO] Saved 204 images to ../data/processed/drsmich/jpgs/drsmich_002
# [INFO] Saved 204 images to ../data/processed/drsmich/jpgs/drsmich_003
# [INFO] Saved 204 images to ../data/processed/drsmich/jpgs/drsmich_001

# %%
inputdir = Path("../data/curated/drsprg/DATA_DICOM/")
targetdir = Path("../data/processed/drsprg/jpgs")
inputdir.mkdir(parents=True, exist_ok=True)
for i in os.scandir(inputdir):
    for j in os.scandir(i.path):
        target_dcm_dir = os.path.join(targetdir, (Path(j).parts[-2]))
        source_dcm_image_path = Path(j.path)
        conv_imgs_arr = save(source_dcm_image_path, target_dcm_dir)
        print(f"[INFO] Saved {len(conv_imgs_arr)} images to {target_dcm_dir}")
# Out:
# [INFO] Saved 180 images to ../data/processed/drsprg/jpgs/drsprg